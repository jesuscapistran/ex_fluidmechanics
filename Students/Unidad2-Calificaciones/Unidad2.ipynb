# %%
import pandas as pd
import numpy as np

# %%
#Leer cvs 

alumnosU2 = pd.read_csv('u2_students.csv')
alumnosU2.head()
# Out:
#         Nombre          Apellidos         Dirección de correo electrónico  \
# 0       ADRIAN     ANDRADE RIVERA           adrian.andrade@alumno.buap.mx
# 1          ANA       QUIROZ MEJIA             ana.quirozme@alumno.buap.mx
# 2       ATZIRY    APARICIO OSORIO         atziry.aparicioo@alumno.buap.mx
# 3  CHRISTOPHER  HERNANDEZ RAMIREZ  christopher.hernandezra@alumno.buap.mx
# 4        DANTE    RAMIREZ ALARCON           dante.ramireza@alumno.buap.mx
#
#    Unidad 2 - Mecánica de fluidos (no asistentes)   Puntos  Comentarios  \
# 0                                            100.0     100          NaN
# 1                                             95.0     100          NaN
# 2                                             95.0     100          NaN
# 3                                             79.0     100          NaN
# 4                                             89.0     100          NaN
#
#    Tarea Semana 6  (se aceptan con retraso)   Puntos.1  \
# ...

# %%
alumnos = alumnosU2['Nombre', 'Unidad 2 - Mecánica de fluidos (no asistentes)']
alumnos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Nombre', 'Unidad 2 - Mecánica de fluidos (no asistentes)')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
