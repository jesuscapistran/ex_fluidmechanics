# %% [markdown]
# # 2-48 Compresibilidad
#
# Un dispositivo sin fricción de pistón y cilindro contiene 10 kg de agua a 20 ºC a presión atmosférica. Luego se aplica una fuerza externa $F$ sobre el pistón hasta que la presión dentro del cilindro aumenta a $100 \: atm$. Suponiendo que el coeficiente de compresibilidad del agua permanece sin cambios durante la compresión: Estime la energía necesaria para comprimir el agua de manera isotérmica. (Respuesta = 29.4 J)
#
# ![Screen Shot 2021-09-28 at 8.34.11.png](data:image/png;base64,...)

# %% [markdown]
# ## Datos
#
# + Fluido: agua
# + T1 = 20 ºC
# + m =  10 kg
# + P1 = 1 atm
# + P2 = 100 atm
# + $k$ es constante en todo el proceso
# + Proceso isotermico (T = cte = 20ºC)
# + F = ?  (Variable)
#
# Calcular la energía necesaria para comprimir el agua

# %% [markdown]
# ## Ecuación relacionada
#
# 1. Coeficiente de compresibilidad (Constante) $k = - v \frac{\partial P}{\partial v} = \rho \frac{\partial P}{\partial \rho} $
#
# 2. Fuerza ejercida sobre el cilindo (Presión)
#
# 3. Trabajo realizado

# %%
#Declarar constantes y variables

# %%
# Función que calcula densidad a distancia z (d_rho)

# %%
# Realizar cálculos

# %%
# Presentar resultados [kg/m3]
